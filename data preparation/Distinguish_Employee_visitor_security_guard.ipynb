# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime

# %%
# read all floor clean data csv
data = pd.read_csv('ALL_Floor_clean_data_new.csv')
data
# Out:
#                ClientMacAddr            localtime       Site      Level  \
# 0          00:00:11:11:31:10  2019-08-23 12:05:05  UK Office  2nd Floor
# 1          00:00:11:11:31:10  2019-08-23 12:05:15  UK Office  2nd Floor
# 2          00:00:11:11:31:10  2019-08-23 12:05:25  UK Office  2nd Floor
# 3          00:00:11:11:31:10  2019-08-23 12:05:35  UK Office  2nd Floor
# 4          00:00:11:11:31:10  2019-08-23 12:05:45  UK Office  2nd Floor
# ...                      ...                  ...        ...        ...
# 271543848  fd:9d:22:20:b6:a1  2020-08-26 13:46:46  UK Office  2nd Floor
# 271543849  fd:9d:22:20:b6:a1  2020-08-26 13:46:56  UK Office  2nd Floor
# 271543850  fd:9d:22:20:b6:a1  2020-08-26 13:47:04  UK Office  2nd Floor
# 271543851  fd:9d:22:20:b6:a1  2020-08-26 13:47:15  UK Office  2nd Floor
# 271543852  fd:9d:22:20:b6:a1  2020-08-26 13:47:22  UK Office  2nd Floor
#
#                  lat       lng
# 0          51.460346 -0.933065
# 1          51.460346 -0.933065
# ...

# %%
# read macid data
macid = pd.read_csv('device_list.csv')
macid
# Out:
#             ClientMacAddr                         Manufacturer    Type  \
# 0       6c:96:cf:ca:e0:9c                          Apple, Inc.  Mobile
# 1       5c:5f:67:8b:e2:64                      Intel Corporate     TBD
# 2       10:02:b5:e3:08:46                      Intel Corporate     TBD
# 3       08:c5:e1:53:31:49  SAMSUNG ELECTRO-MECHANICS(THAILAND)  Mobile
# 4       9c:da:3e:69:ca:fd                      Intel Corporate     TBD
# ...                   ...                                  ...     ...
# 117642  34:f6:4b:46:1e:ed                      Intel Corporate     TBD
# 117643  00:10:20:cf:8a:8f               Hand Held Products Inc   Other
# 117644  34:f6:4b:ca:69:61                      Intel Corporate     TBD
# 117645  34:f6:4b:6d:18:fd                      Intel Corporate     TBD
# 117646  34:f6:4b:b2:00:1b                      Intel Corporate     TBD
#
#                 Sub_Type
# 0                    NaN
# 1                    NaN
# 2                    NaN
# ...

# %%
# find mac address under Mobile category
macid_1 = macid[macid['Type'] == 'Mobile']
macid_1
# Out:
#             ClientMacAddr                             Manufacturer    Type  \
# 0       6c:96:cf:ca:e0:9c                              Apple, Inc.  Mobile
# 3       08:c5:e1:53:31:49      SAMSUNG ELECTRO-MECHANICS(THAILAND)  Mobile
# 8       b0:9f:ba:a7:91:1b                              Apple, Inc.  Mobile
# 9       88:66:a5:56:12:8e                              Apple, Inc.  Mobile
# 13      98:10:e8:3b:08:d7                              Apple, Inc.  Mobile
# ...                   ...                                      ...     ...
# 117570  04:d3:95:bc:2b:28  Motorola Mobility LLC, a Lenovo Company  Mobile
# 117571  c0:e8:62:e1:b7:f2                              Apple, Inc.  Mobile
# 117572  88:9f:6f:4d:45:2e              Samsung Electronics Co.,Ltd  Mobile
# 117605  00:08:22:a4:ba:fb                               InPro Comm  Mobile
# 117606  dc:08:0f:95:fc:57                              Apple, Inc.  Mobile
#
#        Sub_Type
# 0           NaN
# 3           NaN
# ...

# %%
data_1 = data[data['ClientMacAddr'].isin(macid_1['ClientMacAddr'])]
data_1
# Out:
#                ClientMacAddr            localtime       Site      Level  \
# 32         00:02:f7:2f:7a:d1  2020-01-14 13:02:25  UK Office  3rd Floor
# 33         00:02:f7:2f:7a:d1  2020-01-14 13:02:35  UK Office  3rd Floor
# 34         00:02:f7:2f:7a:d1  2020-01-14 13:02:45  UK Office  3rd Floor
# 35         00:02:f7:2f:7a:d1  2020-01-14 13:02:55  UK Office  3rd Floor
# 36         00:02:f7:2f:7a:d1  2020-01-14 13:03:05  UK Office  3rd Floor
# ...                      ...                  ...        ...        ...
# 271543809  fc:fc:48:36:16:6b  2020-01-17 13:38:56  UK Office  1st Floor
# 271543810  fc:fc:48:36:16:6b  2020-01-17 13:39:23  UK Office  1st Floor
# 271543811  fc:fc:48:36:16:6b  2020-01-17 13:39:43  UK Office  1st Floor
# 271543812  fc:fc:48:36:16:6b  2020-01-17 13:47:10  UK Office  1st Floor
# 271543813  fc:fc:48:36:16:6b  2020-01-17 13:49:45  UK Office  1st Floor
#
#                  lat       lng
# 32         51.460470 -0.933168
# 33         51.460470 -0.933168
# ...

# %%
# find mobile devices under TBD catefory
# all devices under TBD category
macid_2 = macid[macid['Type'] == 'TBD']
macid_2
# Out:
#             ClientMacAddr     Manufacturer Type Sub_Type
# 1       5c:5f:67:8b:e2:64  Intel Corporate  TBD      NaN
# 2       10:02:b5:e3:08:46  Intel Corporate  TBD      NaN
# 4       9c:da:3e:69:ca:fd  Intel Corporate  TBD      NaN
# 5       10:02:b5:e3:09:81  Intel Corporate  TBD      NaN
# 6       5c:5f:67:8b:1b:a9  Intel Corporate  TBD      NaN
# ...                   ...              ...  ...      ...
# 117641  34:f6:4b:03:56:48  Intel Corporate  TBD      NaN
# 117642  34:f6:4b:46:1e:ed  Intel Corporate  TBD      NaN
# 117644  34:f6:4b:ca:69:61  Intel Corporate  TBD      NaN
# 117645  34:f6:4b:6d:18:fd  Intel Corporate  TBD      NaN
# 117646  34:f6:4b:b2:00:1b  Intel Corporate  TBD      NaN
#
# [5329 rows x 4 columns]

# %%
# Fixed devices under TBD category
fixed_TBD = pd.read_csv('Fixed_device_from_TBD.csv')
fixed_TBD
# Out:
#          ClientMacAddr  distance_mean  distance_median  distance_std  \
# 0    00:00:11:11:31:10       0.034513              0.0      0.185861
# 1    00:24:d6:9c:70:a6       0.179974              0.0      1.003776
# 2    00:27:15:ea:e7:2b       0.106713              0.0      0.500527
# 3    00:28:f8:26:ae:e4       0.153713              0.0      0.517280
# 4    00:6f:5f:1d:f5:d6       0.000000              0.0      0.000000
# ..                 ...            ...              ...           ...
# 226  f8:59:71:27:fc:04       0.031551              0.0      0.185532
# 227  f8:63:3f:68:f0:2e       0.000000              0.0      0.000000
# 228  f8:94:c2:49:80:c7       0.021967              0.0      0.359504
# 229  f8:da:0c:56:43:63       0.000000              0.0      0.000000
# 230  fc:4d:d4:55:31:b4       0.055374              0.0      0.496222
#
#      speed_mean  speed_median  speed_std  speed_max
# 0      0.003451           0.0   0.018586   0.100089
# ...

# %%
# Mobile devices under TBD category
macid_2 = macid_2[~macid_2['ClientMacAddr'].isin(fixed_TBD['ClientMacAddr'])]
macid_2
# Out:
#             ClientMacAddr     Manufacturer Type Sub_Type
# 1       5c:5f:67:8b:e2:64  Intel Corporate  TBD      NaN
# 2       10:02:b5:e3:08:46  Intel Corporate  TBD      NaN
# 4       9c:da:3e:69:ca:fd  Intel Corporate  TBD      NaN
# 5       10:02:b5:e3:09:81  Intel Corporate  TBD      NaN
# 6       5c:5f:67:8b:1b:a9  Intel Corporate  TBD      NaN
# ...                   ...              ...  ...      ...
# 117641  34:f6:4b:03:56:48  Intel Corporate  TBD      NaN
# 117642  34:f6:4b:46:1e:ed  Intel Corporate  TBD      NaN
# 117644  34:f6:4b:ca:69:61  Intel Corporate  TBD      NaN
# 117645  34:f6:4b:6d:18:fd  Intel Corporate  TBD      NaN
# 117646  34:f6:4b:b2:00:1b  Intel Corporate  TBD      NaN
#
# [5098 rows x 4 columns]

# %%
5329 - 231
# Out:
# 5098

# %%
data_2 = data[data['ClientMacAddr'].isin(macid_2['ClientMacAddr'])]
data_2
# Out:
#                ClientMacAddr            localtime       Site      Level  \
# 45         00:04:4b:62:90:4e  2020-02-25 17:16:46  UK Office  2nd Floor
# 46         00:04:4b:62:90:4e  2020-02-25 17:16:57  UK Office  2nd Floor
# 47         00:04:4b:62:90:4e  2020-02-25 17:17:09  UK Office  2nd Floor
# 48         00:04:4b:62:90:4e  2020-02-25 17:17:16  UK Office  2nd Floor
# 49         00:04:4b:62:90:4e  2020-02-25 17:17:26  UK Office  2nd Floor
# ...                      ...                  ...        ...        ...
# 271543848  fd:9d:22:20:b6:a1  2020-08-26 13:46:46  UK Office  2nd Floor
# 271543849  fd:9d:22:20:b6:a1  2020-08-26 13:46:56  UK Office  2nd Floor
# 271543850  fd:9d:22:20:b6:a1  2020-08-26 13:47:04  UK Office  2nd Floor
# 271543851  fd:9d:22:20:b6:a1  2020-08-26 13:47:15  UK Office  2nd Floor
# 271543852  fd:9d:22:20:b6:a1  2020-08-26 13:47:22  UK Office  2nd Floor
#
#                  lat       lng
# 45         51.460616 -0.932282
# 46         51.460616 -0.932282
# ...

# %%
# all records of mobile devices
data = pd.concat([data_1, data_2])

# %%
data
# Out:
#                ClientMacAddr            localtime       Site      Level  \
# 32         00:02:f7:2f:7a:d1  2020-01-14 13:02:25  UK Office  3rd Floor
# 33         00:02:f7:2f:7a:d1  2020-01-14 13:02:35  UK Office  3rd Floor
# 34         00:02:f7:2f:7a:d1  2020-01-14 13:02:45  UK Office  3rd Floor
# 35         00:02:f7:2f:7a:d1  2020-01-14 13:02:55  UK Office  3rd Floor
# 36         00:02:f7:2f:7a:d1  2020-01-14 13:03:05  UK Office  3rd Floor
# ...                      ...                  ...        ...        ...
# 271543848  fd:9d:22:20:b6:a1  2020-08-26 13:46:46  UK Office  2nd Floor
# 271543849  fd:9d:22:20:b6:a1  2020-08-26 13:46:56  UK Office  2nd Floor
# 271543850  fd:9d:22:20:b6:a1  2020-08-26 13:47:04  UK Office  2nd Floor
# 271543851  fd:9d:22:20:b6:a1  2020-08-26 13:47:15  UK Office  2nd Floor
# 271543852  fd:9d:22:20:b6:a1  2020-08-26 13:47:22  UK Office  2nd Floor
#
#                  lat       lng
# 32         51.460470 -0.933168
# 33         51.460470 -0.933168
# ...

# %%
128907341 + 123482389
# Out:
# 252389730

# %%
# save as csv
data.to_csv('Total_Mobile_data.csv', index=False)

# %%
data = pd.read_csv('Total_Mobile_data.csv')
data
# Out:
#                ClientMacAddr            localtime       Site      Level  \
# 0          00:02:f7:2f:7a:d1  2020-01-14 13:02:25  UK Office  3rd Floor
# 1          00:02:f7:2f:7a:d1  2020-01-14 13:02:35  UK Office  3rd Floor
# 2          00:02:f7:2f:7a:d1  2020-01-14 13:02:45  UK Office  3rd Floor
# 3          00:02:f7:2f:7a:d1  2020-01-14 13:02:55  UK Office  3rd Floor
# 4          00:02:f7:2f:7a:d1  2020-01-14 13:03:05  UK Office  3rd Floor
# ...                      ...                  ...        ...        ...
# 252389725  fd:9d:22:20:b6:a1  2020-08-26 13:46:46  UK Office  2nd Floor
# 252389726  fd:9d:22:20:b6:a1  2020-08-26 13:46:56  UK Office  2nd Floor
# 252389727  fd:9d:22:20:b6:a1  2020-08-26 13:47:04  UK Office  2nd Floor
# 252389728  fd:9d:22:20:b6:a1  2020-08-26 13:47:15  UK Office  2nd Floor
# 252389729  fd:9d:22:20:b6:a1  2020-08-26 13:47:22  UK Office  2nd Floor
#
#                  lat       lng
# 0          51.460470 -0.933168
# 1          51.460470 -0.933168
# ...

# %%
M_data = data.groupby('ClientMacAddr').agg(no_meaning = ('Level', 'nunique')).reset_index()
M_data
# Out:
#             ClientMacAddr  no_meaning
# 0       00:02:f7:2f:7a:d1           1
# 1       00:04:4b:62:90:4e           1
# 2       00:07:88:d8:94:64           2
# 3       00:08:22:00:b9:fb           2
# 4       00:08:22:08:4c:fc           1
# ...                   ...         ...
# 104967  fc:f8:ae:5a:6f:ea           1
# 104968  fc:fc:48:36:16:6b           2
# 104969  fd:6a:eb:32:d4:cd           1
# 104970  fd:9a:58:da:cb:ea           1
# 104971  fd:9d:22:20:b6:a1           1
#
# [104972 rows x 2 columns]

# %%
M_data.to_csv('Total_Mobile_data_ClientMacAddr.csv', index=False)

# %%
M_data = pd.read_csv('Total_Mobile_data_ClientMacAddr.csv')

# %%
# read count of day
count_of_day = pd.read_csv('ALL_Floor_data_count_of_day.csv')
count_of_day
# Out:
#             ClientMacAddr  count_of_day
# 0       00:00:11:11:31:10             3
# 1       00:02:f7:2f:7a:d1             1
# 2       00:04:4b:62:90:4e             1
# 3       00:06:c6:5a:a2:51             2
# 4       00:06:c6:8f:0a:35             1
# ...                   ...           ...
# 113025  fc:f8:ae:5a:6f:ea             1
# 113026  fc:fc:48:36:16:6b             1
# 113027  fd:6a:eb:32:d4:cd             1
# 113028  fd:9a:58:da:cb:ea             1
# 113029  fd:9d:22:20:b6:a1             1
#
# [113030 rows x 2 columns]

# %%
count_of_day = count_of_day[count_of_day['ClientMacAddr'].isin(M_data['ClientMacAddr'])]
count_of_day
# Out:
#             ClientMacAddr  count_of_day
# 1       00:02:f7:2f:7a:d1             1
# 2       00:04:4b:62:90:4e             1
# 6       00:07:88:d8:94:64             1
# 7       00:08:22:00:b9:fb             1
# 8       00:08:22:08:4c:fc             1
# ...                   ...           ...
# 113025  fc:f8:ae:5a:6f:ea             1
# 113026  fc:fc:48:36:16:6b             1
# 113027  fd:6a:eb:32:d4:cd             1
# 113028  fd:9a:58:da:cb:ea             1
# 113029  fd:9d:22:20:b6:a1             1
#
# [104972 rows x 2 columns]

# %%
# cumulative distribution chart for count of day
data_use = count_of_day.sort_values('count_of_day',ascending = True)
data_use['count'] = 1
data_use
# Out:
#             ClientMacAddr  count_of_day  count
# 1       00:02:f7:2f:7a:d1             1      1
# 72327   80:58:f8:eb:8a:60             1      1
# 72321   80:58:f8:eb:77:29             1      1
# 72320   80:58:f8:eb:73:93             1      1
# 72319   80:58:f8:eb:68:bf             1      1
# ...                   ...           ...    ...
# 95342   9c:8c:6e:46:1c:5e           365      1
# 95341   9c:8c:6e:46:0c:52           365      1
# 95340   9c:8c:6e:46:0b:7c           365      1
# 95339   9c:8c:6e:46:01:f8           365      1
# 112927  fc:03:9f:07:af:f4           365      1
#
# [104972 rows x 3 columns]

# %%
x = data_use['count_of_day']
y = data_use['count']
cumulative_y = [sum(y[:i+1]) for i in range(len(y))]
plt.plot(x, cumulative_y)

# %%
x = data_use['count_of_day']
y = data_use['count']
cumulative_y = [sum(y[:i+1]) for i in range(len(y))]
plt.plot(x, cumulative_y)
plt.xlim(0, 20)
plt.savefig('count_of_day_20.png')

# %%
x = data_use['count_of_day']
y = data_use['count']
cumulative_y = [sum(y[:i+1]) for i in range(len(y))]
plt.plot(x, cumulative_y)
plt.xlim(0, 10)
plt.savefig('count_of_day_10.png')

# %%
# read device list
device_list = pd.read_csv('device_list.csv')
device_list
# Out:
#             ClientMacAddr                         Manufacturer    Type  \
# 0       6c:96:cf:ca:e0:9c                          Apple, Inc.  Mobile
# 1       5c:5f:67:8b:e2:64                      Intel Corporate     TBD
# 2       10:02:b5:e3:08:46                      Intel Corporate     TBD
# 3       08:c5:e1:53:31:49  SAMSUNG ELECTRO-MECHANICS(THAILAND)  Mobile
# 4       9c:da:3e:69:ca:fd                      Intel Corporate     TBD
# ...                   ...                                  ...     ...
# 117642  34:f6:4b:46:1e:ed                      Intel Corporate     TBD
# 117643  00:10:20:cf:8a:8f               Hand Held Products Inc   Other
# 117644  34:f6:4b:ca:69:61                      Intel Corporate     TBD
# 117645  34:f6:4b:6d:18:fd                      Intel Corporate     TBD
# 117646  34:f6:4b:b2:00:1b                      Intel Corporate     TBD
#
#                 Sub_Type
# 0                    NaN
# 1                    NaN
# 2                    NaN
# ...

# %%
# merge
device_day = pd.merge(count_of_day, device_list, how='left', on='ClientMacAddr')
device_day
# Out:
#             ClientMacAddr  count_of_day     Manufacturer    Type Sub_Type
# 0       00:02:f7:2f:7a:d1             1              ARM  Mobile      NaN
# 1       00:04:4b:62:90:4e             1           NVIDIA     TBD      NaN
# 2       00:07:88:d8:94:64             1   Clipcomm, Inc.     TBD      NaN
# 3       00:08:22:00:b9:fb             1       InPro Comm  Mobile      NaN
# 4       00:08:22:08:4c:fc             1       InPro Comm  Mobile      NaN
# ...                   ...           ...              ...     ...      ...
# 104967  fc:f8:ae:5a:6f:ea             1  Intel Corporate     TBD      NaN
# 104968  fc:fc:48:36:16:6b             1      Apple, Inc.  Mobile      NaN
# 104969  fd:6a:eb:32:d4:cd             1          unknown     TBD      NaN
# 104970  fd:9a:58:da:cb:ea             1          unknown     TBD      NaN
# 104971  fd:9d:22:20:b6:a1             1          unknown     TBD      NaN
#
# [104972 rows x 5 columns]

# %%
# visitor devices - threshold of count of day : 10
visitors = device_day[device_day['count_of_day']<=10]
visitors
# Out:
#             ClientMacAddr  count_of_day     Manufacturer    Type Sub_Type
# 0       00:02:f7:2f:7a:d1             1              ARM  Mobile      NaN
# 1       00:04:4b:62:90:4e             1           NVIDIA     TBD      NaN
# 2       00:07:88:d8:94:64             1   Clipcomm, Inc.     TBD      NaN
# 3       00:08:22:00:b9:fb             1       InPro Comm  Mobile      NaN
# 4       00:08:22:08:4c:fc             1       InPro Comm  Mobile      NaN
# ...                   ...           ...              ...     ...      ...
# 104967  fc:f8:ae:5a:6f:ea             1  Intel Corporate     TBD      NaN
# 104968  fc:fc:48:36:16:6b             1      Apple, Inc.  Mobile      NaN
# 104969  fd:6a:eb:32:d4:cd             1          unknown     TBD      NaN
# 104970  fd:9a:58:da:cb:ea             1          unknown     TBD      NaN
# 104971  fd:9d:22:20:b6:a1             1          unknown     TBD      NaN
#
# [99572 rows x 5 columns]

# %%
visitors.to_csv('visitors_list.csv', index=False)

# %%
employee = device_day[device_day['count_of_day']>10]
employee
# Out:
#             ClientMacAddr  count_of_day  \
# 116     00:23:32:28:05:a2            17
# 123     00:26:c6:6d:02:3e           214
# 130     00:28:f8:4e:29:24            13
# 158     00:61:71:81:d2:05            11
# 169     00:6d:52:2d:b5:2f            15
# ...                   ...           ...
# 104880  f8:c3:9e:be:08:e0            14
# 104886  f8:e0:79:eb:48:68            13
# 104911  f8:ff:c2:8e:48:d9            43
# 104922  fc:03:9f:07:af:f4           365
# 104939  fc:45:96:12:d1:4b            98
#
#                                    Manufacturer    Type Sub_Type
# 116                                 Apple, Inc.  Mobile      NaN
# 123                             Intel Corporate     TBD      NaN
# 130                             Intel Corporate     TBD      NaN
# 158                                 Apple, Inc.  Mobile      NaN
# 169                                 Apple, Inc.  Mobile      NaN
# ...                                         ...     ...      ...
# ...

# %%
employee.to_csv('employee_list.csv', index=False)

# %%
employee_data = data[data['ClientMacAddr'].isin(employee['ClientMacAddr'])]
employee_data
# Out:
#                ClientMacAddr            localtime       Site      Level  \
# 7939       00:23:32:28:05:a2  2019-11-11 10:20:28  UK Office  2nd Floor
# 7940       00:23:32:28:05:a2  2019-11-11 10:20:39  UK Office  2nd Floor
# 7941       00:23:32:28:05:a2  2019-11-11 10:20:49  UK Office  2nd Floor
# 7942       00:23:32:28:05:a2  2019-11-11 10:20:59  UK Office  2nd Floor
# 7943       00:23:32:28:05:a2  2019-11-11 10:21:09  UK Office  2nd Floor
# ...                      ...                  ...        ...        ...
# 252385329  f8:94:c2:f2:17:55  2019-10-25 16:50:49  UK Office  2nd Floor
# 10    10               5081
# 11    11               5033
# 12    12               5024
# 13    13               5082
# 14    14               5004
# 15    15               4965
# 16    16               4780
# 17    17               2923
# 18    18               1734
# 19    19               1112
# 20    20                786
# 21    21                573
# 22    22                470
# 23    23                369

# %%
employee_hour.to_csv('employee_hour.csv', index=False)

# %%
# hourly distribution graph of all employees' mobile devices
plt.figure(figsize=(16,9))
plt.bar(employee_hour['hour'], employee_hour['Number_of_Devices'])

# Add title and labels for axes

plt.xlabel("Hour")
plt.ylabel("Number of Activated Devices")
# Display the chart
plt.show()

# %%
# night_time_1
employee_data['night_time_1'] = employee_data['hour'].apply(lambda x : 1 if x<7 or x>18 else 0)
employee_data
# Out:
#                ClientMacAddr            localtime       Site      Level  \
# 0          00:23:32:28:05:a2  2019-11-11 10:20:28  UK Office  2nd Floor
# 1          00:23:32:28:05:a2  2019-11-11 10:20:39  UK Office  2nd Floor
# 2          00:23:32:28:05:a2  2019-11-11 10:20:49  UK Office  2nd Floor
# 3          00:23:32:28:05:a2  2019-11-11 10:20:59  UK Office  2nd Floor
# 4          00:23:32:28:05:a2  2019-11-11 10:21:09  UK Office  2nd Floor
# ...                      ...                  ...        ...        ...
# 236824744  f8:94:c2:f2:17:55  2019-10-25 16:50:49  UK Office  2nd Floor
# 236824745  f8:94:c2:f2:17:55  2019-10-25 16:50:54  UK Office  2nd Floor
# 236824746  f8:94:c2:f2:17:55  2019-10-25 16:51:09  UK Office  2nd Floor
# 236824747  f8:94:c2:f2:17:55  2019-10-25 16:51:15  UK Office  2nd Floor
# 236824748  f8:94:c2:f2:17:55  2019-10-25 16:51:25  UK Office  2nd Floor
#
#                  lat       lng  hour  night_time_1
# 0          51.460356 -0.932823    10             0
# ...

# %%
night_1 = employee_data[employee_data['night_time_1'] == 1]
night_1
# Out:
#                ClientMacAddr            localtime       Site         Level  \
# 5917       00:80:92:df:7b:97  2019-08-12 19:00:08  UK Office  Ground Floor
# 5918       00:80:92:df:7b:97  2019-08-12 19:00:18  UK Office  Ground Floor
# 5919       00:80:92:df:7b:97  2019-08-12 19:00:28  UK Office  Ground Floor
# 5920       00:80:92:df:7b:97  2019-08-12 19:00:39  UK Office  Ground Floor
# 5921       00:80:92:df:7b:97  2019-08-12 19:00:49  UK Office  Ground Floor
# ...                      ...                  ...        ...           ...
# 236821656  f8:94:c2:f2:17:55  2019-10-24 19:46:38  UK Office     2nd Floor
# 236821657  f8:94:c2:f2:17:55  2019-10-24 19:46:43  UK Office     2nd Floor
# 236821658  f8:94:c2:f2:17:55  2019-10-24 19:49:36  UK Office     2nd Floor
# 236821659  f8:94:c2:f2:17:55  2019-10-24 19:49:46  UK Office     2nd Floor
# 236821660  f8:94:c2:f2:17:55  2019-10-24 19:49:56  UK Office     2nd Floor
#
#                  lat       lng  hour  night_time_1
# ...

# %%
night_1['ClientMacAddr'].nunique()
# Out:
# 1233

# %%
count_of_day = pd.read_csv('ALL_Floor_data_count_of_day.csv')
count_of_day
# Out:
#             ClientMacAddr  count_of_day
# 0       00:00:11:11:31:10             3
# 1       00:02:f7:2f:7a:d1             1
# 2       00:04:4b:62:90:4e             1
# 3       00:06:c6:5a:a2:51             2
# 4       00:06:c6:8f:0a:35             1
# ...                   ...           ...
# 113025  fc:f8:ae:5a:6f:ea             1
# 113026  fc:fc:48:36:16:6b             1
# 113027  fd:6a:eb:32:d4:cd             1
# 113028  fd:9a:58:da:cb:ea             1
# 113029  fd:9d:22:20:b6:a1             1
#
# [113030 rows x 2 columns]

# %%
# night_time_2
employee_data['night_time_2'] = employee_data['hour'].apply(lambda x : 1 if x<6 or x>22 else 0)
employee_data
# Out:
#                ClientMacAddr            localtime       Site      Level  \
# 0          00:23:32:28:05:a2  2019-11-11 10:20:28  UK Office  2nd Floor
# 1          00:23:32:28:05:a2  2019-11-11 10:20:39  UK Office  2nd Floor
# 2          00:23:32:28:05:a2  2019-11-11 10:20:49  UK Office  2nd Floor
# 3          00:23:32:28:05:a2  2019-11-11 10:20:59  UK Office  2nd Floor
# 4          00:23:32:28:05:a2  2019-11-11 10:21:09  UK Office  2nd Floor
# ...                      ...                  ...        ...        ...
# 236824744  f8:94:c2:f2:17:55  2019-10-25 16:50:49  UK Office  2nd Floor
# 236824745  f8:94:c2:f2:17:55  2019-10-25 16:50:54  UK Office  2nd Floor
# 236824746  f8:94:c2:f2:17:55  2019-10-25 16:51:09  UK Office  2nd Floor
# 236824747  f8:94:c2:f2:17:55  2019-10-25 16:51:15  UK Office  2nd Floor
# 236824748  f8:94:c2:f2:17:55  2019-10-25 16:51:25  UK Office  2nd Floor
#
#                  lat       lng  hour  night_time_1  night_time_2  \
# ...

# %%
night_2 = employee_data[employee_data['night_time_2'] == 1]
night_2
# Out:
#                ClientMacAddr            localtime       Site         Level  \
# 7233       00:80:92:df:7b:97  2019-08-12 23:00:05  UK Office  Ground Floor
# 7234       00:80:92:df:7b:97  2019-08-12 23:00:15  UK Office  Ground Floor
# 7235       00:80:92:df:7b:97  2019-08-12 23:00:25  UK Office  Ground Floor
# 7236       00:80:92:df:7b:97  2019-08-12 23:00:35  UK Office  Ground Floor
# 7237       00:80:92:df:7b:97  2019-08-12 23:00:45  UK Office  Ground Floor
# ...                      ...                  ...        ...           ...
# 236774034  f8:63:3f:51:22:d2  2020-09-01 23:58:08  UK Office     3rd Floor
# 236774035  f8:63:3f:51:22:d2  2020-09-01 23:58:15  UK Office     3rd Floor
# 236774036  f8:63:3f:51:22:d2  2020-09-01 23:58:29  UK Office     3rd Floor
# 236774037  f8:63:3f:51:22:d2  2020-09-01 23:58:35  UK Office     3rd Floor
# 236774038  f8:63:3f:51:22:d2  2020-09-01 23:58:48  UK Office     3rd Floor
#
#                  lat       lng  hour  night_time_1  night_time_2  \
# ...

# %%
night_2['ClientMacAddr'].nunique()
# Out:
# 406

# %%
# night_time_3
employee_data['night_time_3'] = employee_data['hour'].apply(lambda x : 1 if x<4 or x>23 else 0)
employee_data
# Out:
#                ClientMacAddr            localtime       Site      Level  \
# 0          00:23:32:28:05:a2  2019-11-11 10:20:28  UK Office  2nd Floor
# 1          00:23:32:28:05:a2  2019-11-11 10:20:39  UK Office  2nd Floor
# 236766124  f8:63:3f:51:22:d2  2020-09-01 01:59:46  UK Office     3rd Floor
# 236766125  f8:63:3f:51:22:d2  2020-09-01 01:59:56  UK Office     3rd Floor
#
#                  lat       lng  hour  night_time_1  night_time_2  \
# ...

# %%
night_5['ClientMacAddr'].nunique()
# Out:
# 367

# %%
# test
random = night_2.sample(n=5)
random = random[['ClientMacAddr','night_time_2']]
random
# Out:
#                ClientMacAddr  night_time_2
# 35105584   88:29:9c:da:d9:f9             1
# 12832258   30:07:4d:5e:a6:6c             1
# 14615598   38:f9:d3:20:31:32             1
# 149241914  48:a4:72:ae:11:81             1
# 11062463   24:1b:7a:9d:05:c7             1

# %%
# test 1 
use_data = employee_data[employee_data['ClientMacAddr']=='88:29:9c:da:d9:f9']

plt.figure(figsize=(16,9))

# Plot the enclosed shape
b = [51.46094763183397, 
     51.46092976598236,
     51.460257062787136,
     51.46033182761984,
     51.46055317954987,
     51.46051343244503,
     51.46094763183397]
a = [-0.9324647751707785,
     -0.9321732468412318,
     -0.9322924232674887,
     -0.9332446313023279,
     -0.9332078677279798,
     -0.9325475994237232,
     -0.9324647751707785]
plt.plot(a,b)
plt.scatter('lng','lat',data = use_data, s = 2)

# Set the x and y limits of the plot
plt.xlim(-0.9333, -0.93215)
plt.ylim(51.46025, 51.460962917873445)

# Remove the x ticks and y ticks
plt.xticks([])
plt.yticks([])

# Set the x and y labels of the plot
plt.xlabel('Longtitude')
plt.ylabel('Latitude')

# Show the plot
plt.show()

# %%
# test 2 
use_data = employee_data[employee_data['ClientMacAddr']=='30:07:4d:5e:a6:6c']

plt.figure(figsize=(16,9))

# Plot the enclosed shape
b = [51.46094763183397, 
     51.46092976598236,
     51.460257062787136,
     51.46033182761984,
     51.46055317954987,
     51.46051343244503,
     51.46094763183397]
a = [-0.9324647751707785,
     -0.9321732468412318,
     -0.9322924232674887,
     -0.9332446313023279,
     -0.9332078677279798,
     -0.9325475994237232,
     -0.9324647751707785]
plt.plot(a,b)
plt.scatter('lng','lat',data = use_data, s = 2)

# Set the x and y limits of the plot
plt.xlim(-0.9333, -0.93215)
plt.ylim(51.46025, 51.460962917873445)

# Remove the x ticks and y ticks
plt.xticks([])
plt.yticks([])

# Set the x and y labels of the plot
plt.xlabel('Longtitude')
plt.ylabel('Latitude')

# Show the plot
plt.show()

# %%
# test 3
use_data = employee_data[employee_data['ClientMacAddr']=='38:f9:d3:20:31:32']

plt.figure(figsize=(16,9))

# Plot the enclosed shape
b = [51.46094763183397, 
     51.46092976598236,
     51.460257062787136,
     51.46033182761984,
     51.46055317954987,
     51.46051343244503,
     51.46094763183397]
a = [-0.9324647751707785,
     -0.9321732468412318,
     -0.9322924232674887,
     -0.9332446313023279,
     -0.9332078677279798,
     -0.9325475994237232,
     -0.9324647751707785]
plt.plot(a,b)
plt.scatter('lng','lat',data = use_data, s = 2)

# Set the x and y limits of the plot
plt.xlim(-0.9333, -0.93215)
plt.ylim(51.46025, 51.460962917873445)

# Remove the x ticks and y ticks
plt.xticks([])
plt.yticks([])

# Set the x and y labels of the plot
plt.xlabel('Longtitude')
plt.ylabel('Latitude')

# Show the plot
plt.show()

# %%
employee_data[employee_data['ClientMacAddr']=='38:f9:d3:20:31:32']
# Out:
#               ClientMacAddr            localtime       Site      Level  \
# 14615382  38:f9:d3:20:31:32  2020-05-11 09:08:28  UK Office  2nd Floor
# 14615383  38:f9:d3:20:31:32  2020-05-11 09:08:36  UK Office  2nd Floor
# 14615384  38:f9:d3:20:31:32  2020-05-11 09:08:48  UK Office  2nd Floor
# 14615385  38:f9:d3:20:31:32  2020-05-11 09:08:52  UK Office  2nd Floor
# 14615386  38:f9:d3:20:31:32  2020-05-11 09:09:06  UK Office  2nd Floor
# ...                     ...                  ...        ...        ...
# 14616261  38:f9:d3:20:31:32  2020-08-29 02:18:26  UK Office  2nd Floor
# 14616262  38:f9:d3:20:31:32  2020-08-29 02:18:39  UK Office  2nd Floor
# 14616263  38:f9:d3:20:31:32  2020-08-29 02:18:49  UK Office  2nd Floor
# 14616264  38:f9:d3:20:31:32  2020-08-29 02:18:56  UK Office  2nd Floor
# 14616265  38:f9:d3:20:31:32  2020-08-29 02:19:03  UK Office  2nd Floor
#
#                 lat       lng  hour  night_time_1  night_time_2  night_time_3  \
# ...

# %%
count_of_day[count_of_day['ClientMacAddr']=='38:f9:d3:20:31:32']
# Out:
#            ClientMacAddr  count_of_day
# 24736  38:f9:d3:20:31:32            13

# %%
device_list = pd.read_csv('device_list.csv')
device_list[device_list['ClientMacAddr']=='38:f9:d3:20:31:32']
# Out:
#           ClientMacAddr Manufacturer    Type Sub_Type
# 1349  38:f9:d3:20:31:32  Apple, Inc.  Mobile      NaN

# %%
# test 4 
use_data = employee_data[employee_data['ClientMacAddr']=='48:a4:72:ae:11:81']

plt.figure(figsize=(16,9))

# Plot the enclosed shape
b = [51.46094763183397, 
     51.46092976598236,
     51.460257062787136,
     51.46033182761984,
     51.46055317954987,
     51.46051343244503,
     51.46094763183397]
a = [-0.9324647751707785,
     -0.9321732468412318,
     -0.9322924232674887,
     -0.9332446313023279,
     -0.9332078677279798,
     -0.9325475994237232,
     -0.9324647751707785]
plt.plot(a,b)
plt.scatter('lng','lat',data = use_data, s = 2)

# Set the x and y limits of the plot
plt.xlim(-0.9333, -0.93215)
plt.ylim(51.46025, 51.460962917873445)

# Remove the x ticks and y ticks
plt.xticks([])
plt.yticks([])

# Set the x and y labels of the plot
plt.xlabel('Longtitude')
plt.ylabel('Latitude')

# Show the plot
plt.show()

# %%
count_of_day[count_of_day['ClientMacAddr']=='48:a4:72:ae:11:81']
# Out:
#            ClientMacAddr  count_of_day
# 25602  48:a4:72:ae:11:81           364

# %%
device_list[device_list['ClientMacAddr']=='48:a4:72:ae:11:81']
# Out:
#          ClientMacAddr     Manufacturer Type Sub_Type
# 210  48:a4:72:ae:11:81  Intel Corporate  TBD      NaN

# %%
# test 5 
use_data = employee_data[employee_data['ClientMacAddr']=='24:1b:7a:9d:05:c7']

plt.figure(figsize=(16,9))

# Plot the enclosed shape
b = [51.46094763183397, 
     51.46092976598236,
     51.460257062787136,
     51.46033182761984,
     51.46055317954987,
     51.46051343244503,
     51.46094763183397]
a = [-0.9324647751707785,
     -0.9321732468412318,
     -0.9322924232674887,
     -0.9332446313023279,
     -0.9332078677279798,
     -0.9325475994237232,
     -0.9324647751707785]
plt.plot(a,b)
plt.scatter('lng','lat',data = use_data, s = 2)

# Set the x and y limits of the plot
plt.xlim(-0.9333, -0.93215)
plt.ylim(51.46025, 51.460962917873445)

# Remove the x ticks and y ticks
plt.xticks([])
plt.yticks([])

# Set the x and y labels of the plot
plt.xlabel('Longtitude')
plt.ylabel('Latitude')

# Show the plot
plt.show()

# %%
employee_data[employee_data['ClientMacAddr']=='24:1b:7a:9d:05:c7']
# Out:
#               ClientMacAddr            localtime       Site         Level  \
# 11045481  24:1b:7a:9d:05:c7  2019-11-28 08:22:59  UK Office  Ground Floor
# 11045482  24:1b:7a:9d:05:c7  2019-11-28 08:23:08  UK Office  Ground Floor
# 11045483  24:1b:7a:9d:05:c7  2019-11-28 08:23:19  UK Office  Ground Floor
# 11045484  24:1b:7a:9d:05:c7  2019-11-28 08:23:28  UK Office  Ground Floor
# 11045485  24:1b:7a:9d:05:c7  2019-11-28 08:23:39  UK Office  Ground Floor
# ...                     ...                  ...        ...           ...
# 11168432  24:1b:7a:9d:05:c7  2020-04-08 13:49:15  UK Office     1st Floor
# 11168433  24:1b:7a:9d:05:c7  2020-04-08 13:49:25  UK Office     1st Floor
# 11168434  24:1b:7a:9d:05:c7  2020-04-08 13:49:38  UK Office     1st Floor
# 11168435  24:1b:7a:9d:05:c7  2020-04-08 13:49:45  UK Office     1st Floor
# 11168436  24:1b:7a:9d:05:c7  2020-04-08 13:49:57  UK Office     1st Floor
#
#                 lat       lng  hour  night_time_1  night_time_2  night_time_3  \
# ...

# %%
count_of_day[count_of_day['ClientMacAddr']=='24:1b:7a:9d:05:c7']
# Out:
#           ClientMacAddr  count_of_day
# 3779  24:1b:7a:9d:05:c7            32

# %%
device_list[device_list['ClientMacAddr']=='24:1b:7a:9d:05:c7']
# Out:
#           ClientMacAddr Manufacturer    Type Sub_Type
# 1991  24:1b:7a:9d:05:c7  Apple, Inc.  Mobile      NaN

# %%
# date
employee_data['date'] = employee_data['localtime'].apply(lambda x:x[:10])
employee_data
# Out:
#                ClientMacAddr            localtime       Site      Level  \
# 0          00:23:32:28:05:a2  2019-11-11 10:20:28  UK Office  2nd Floor
# 1          00:23:32:28:05:a2  2019-11-11 10:20:39  UK Office  2nd Floor
# 2          00:23:32:28:05:a2  2019-11-11 10:20:49  UK Office  2nd Floor
# 3          00:23:32:28:05:a2  2019-11-11 10:20:59  UK Office  2nd Floor
# 4          00:23:32:28:05:a2  2019-11-11 10:21:09  UK Office  2nd Floor
# ...                      ...                  ...        ...        ...
# 236824744  f8:94:c2:f2:17:55  2019-10-25 16:50:49  UK Office  2nd Floor
# 236824745  f8:94:c2:f2:17:55  2019-10-25 16:50:54  UK Office  2nd Floor
# 236824746  f8:94:c2:f2:17:55  2019-10-25 16:51:09  UK Office  2nd Floor
# 236824747  f8:94:c2:f2:17:55  2019-10-25 16:51:15  UK Office  2nd Floor
# 236824748  f8:94:c2:f2:17:55  2019-10-25 16:51:25  UK Office  2nd Floor
#
#                  lat       lng  hour  night_time_1  night_time_2  \
# ...

# %%
# Has the device appeared on weekends?
employee_data['date_time'] = pd.to_datetime(employee_data['date'])
employee_data
# Out:
#                ClientMacAddr            localtime       Site      Level  \
#
#                  lat       lng  hour  night_time_1  night_time_2  \
# ...

# %%
employee_data.to_csv('identify_security_guard.csv', index=False)

# %%
weekend = employee_data[employee_data['weekend']==1]

# %%
weekend['ClientMacAddr'].nunique()
# Out:
# 258

# %%
weekend = pd.DataFrame(weekend.groupby('ClientMacAddr').size().reset_index())
weekend
# Out:
#          ClientMacAddr  0
# 0    00:26:c6:6d:02:3e  1
# 1    00:80:92:df:7b:97  1
# 2    00:c2:c6:cc:a8:85  1
# 3    00:c2:c6:ec:4c:a3  1
# 4    00:c2:c6:f9:2f:9f  1
# ..                 ... ..
# 253  ec:ad:b8:8e:01:ac  1
# 254  f0:c3:71:ae:e5:0c  1
# 255  f4:5c:89:db:fb:7f  1
# 256  f8:63:3f:51:22:d2  1
# 257  fc:03:9f:07:af:f4  1
#
# [258 rows x 2 columns]

# %%
night_2 = pd.DataFrame(night_2.groupby('ClientMacAddr').size().reset_index())
night_2
# Out:
#          ClientMacAddr       0
# 0    00:26:c6:6d:02:3e  326099
# 1    00:80:92:df:7b:97  492241
# 2    00:b3:62:4e:0f:c9       1
# 3    00:c2:c6:cc:a8:85  436465
# 4    00:c2:c6:ec:4c:a3  356915
# ..                 ...     ...
# 401  f0:c1:f1:24:b9:0e      87
# 402  f0:c3:71:ae:e5:0c   24991
# 403  f4:5c:89:db:fb:7f   12571
# 404  f8:63:3f:51:22:d2   27984
# 405  fc:03:9f:07:af:f4  908006
#
# [406 rows x 2 columns]

# %%
security_guard_1 = pd.merge(night_2, weekend, how='outer', on='ClientMacAddr')
security_guard_1
# Out:
#          ClientMacAddr       0_x  0_y
# 0    00:26:c6:6d:02:3e  326099.0  1.0
# 1    00:80:92:df:7b:97  492241.0  1.0
# 2    00:b3:62:4e:0f:c9       1.0  NaN
# 3    00:c2:c6:cc:a8:85  436465.0  1.0
# 4    00:c2:c6:ec:4c:a3  356915.0  1.0
# ..                 ...       ...  ...
# 425  c4:9d:ed:1a:ff:7e       NaN  1.0
# 426  dc:90:88:8d:09:dd       NaN  1.0
# 427  e4:a7:a0:99:bc:90       NaN  1.0
# 428  e4:a7:a0:99:dc:9d       NaN  1.0
# 429  e4:f8:9c:1f:e5:82       NaN  1.0
#
# [430 rows x 3 columns]

# %%
security_guard_1 = security_guard_1[['ClientMacAddr']]
security_guard_1
# Out:
#          ClientMacAddr
# 0    00:26:c6:6d:02:3e
# 1    00:80:92:df:7b:97
# 2    00:b3:62:4e:0f:c9
# 3    00:c2:c6:cc:a8:85
# 4    00:c2:c6:ec:4c:a3
# ..                 ...
# 425  c4:9d:ed:1a:ff:7e
# 426  dc:90:88:8d:09:dd
# 427  e4:a7:a0:99:bc:90
# 428  e4:a7:a0:99:dc:9d
# 429  e4:f8:9c:1f:e5:82
#
# [430 rows x 1 columns]

# %%
device_list[device_list['ClientMacAddr'].isin(security_guard_1['ClientMacAddr'])]['Manufacturer'].value_counts()
# Out:
# Apple, Inc.                                201
# Intel Corporate                            187
# SAMSUNG ELECTRO-MECHANICS(THAILAND)         11
# Samsung Electronics Co.,Ltd                 11
# Hon Hai Precision Ind. Co.,Ltd.              3
# TCT mobile ltd                               3
# Motorola Mobility LLC, a Lenovo Company      3
# Microsoft Corporation                        2
# BlackBerry RTS                               1
# Shenzhen RF Technology Co., Ltd              1
# Liteon Technology Corporation                1
# Rivet Networks                               1
# Huawei Device Co., Ltd.                      1
# Microsoft Mobile Oy                          1
# Sony Corporation                             1
# Silex Technology, Inc.                       1
# HUAWEI TECHNOLOGIES CO.,LTD                  1
# Name: Manufacturer, dtype: int64

# %%
security_guard_1.to_csv('security_guard_430.csv', index=False)

# %%
security_guard_1_data = employee_data[employee_data['ClientMacAddr'].isin(security_guard_1['ClientMacAddr'])]
security_guard_1_data
# Out:
#                ClientMacAddr            localtime       Site         Level  \
# 5799       00:80:92:df:7b:97  2019-08-12 18:27:08  UK Office  Ground Floor
# 5800       00:80:92:df:7b:97  2019-08-12 18:27:18  UK Office  Ground Floor
# 5801       00:80:92:df:7b:97  2019-08-12 18:27:29  UK Office  Ground Floor
# 5802       00:80:92:df:7b:97  2019-08-12 18:27:39  UK Office  Ground Floor
# 5803       00:80:92:df:7b:97  2019-08-12 18:27:49  UK Office  Ground Floor
# ...                      ...                  ...        ...           ...
# 236774034  f8:63:3f:51:22:d2  2020-09-01 23:58:08  UK Office     3rd Floor
# 236774035  f8:63:3f:51:22:d2  2020-09-01 23:58:15  UK Office     3rd Floor
# 236774036  f8:63:3f:51:22:d2  2020-09-01 23:58:29  UK Office     3rd Floor
# 236774037  f8:63:3f:51:22:d2  2020-09-01 23:58:35  UK Office     3rd Floor
# 236774038  f8:63:3f:51:22:d2  2020-09-01 23:58:48  UK Office     3rd Floor
#
#                  lat       lng  hour  night_time_1  night_time_2  \
# ...

# %%
security_guard_1_data.to_csv('security_guard_430_data.csv', index=False)

# %%
security_guard_2 = pd.merge(night_2, weekend, how='inner', on='ClientMacAddr')
security_guard_2
# Out:
#          ClientMacAddr     0_x  0_y
# 0    00:26:c6:6d:02:3e  326099    1
# 1    00:80:92:df:7b:97  492241    1
# 2    00:c2:c6:cc:a8:85  436465    1
# 3    00:c2:c6:ec:4c:a3  356915    1
# 4    00:c2:c6:f9:2f:9f  892272    1
# ..                 ...     ...  ...
# 229  ec:ad:b8:8e:01:ac   19003    1
# 230  f0:c3:71:ae:e5:0c   24991    1
# 231  f4:5c:89:db:fb:7f   12571    1
# 232  f8:63:3f:51:22:d2   27984    1
# 233  fc:03:9f:07:af:f4  908006    1
#
# [234 rows x 3 columns]

# %%
security_guard_2 = security_guard_2[['ClientMacAddr']]
security_guard_2
# Out:
#          ClientMacAddr
# 0    00:26:c6:6d:02:3e
# 1    00:80:92:df:7b:97
# 2    00:c2:c6:cc:a8:85
# 3    00:c2:c6:ec:4c:a3
# 4    00:c2:c6:f9:2f:9f
# ..                 ...
# 229  ec:ad:b8:8e:01:ac
# 230  f0:c3:71:ae:e5:0c
# 231  f4:5c:89:db:fb:7f
# 232  f8:63:3f:51:22:d2
# 233  fc:03:9f:07:af:f4
#
# [234 rows x 1 columns]

# %%
security_guard_2.to_csv('security_guard_234.csv', index=False)

# %%
security_guard_2_data = employee_data[employee_data['ClientMacAddr'].isin(security_guard_2['ClientMacAddr'])]
security_guard_2_data

# %%
security_guard_2_data.to_csv('security_guard_234_data.csv', index=False)

# %%
device_list[device_list['ClientMacAddr'].isin(security_guard_2['ClientMacAddr'])]['Manufacturer'].value_counts()
# Out:
# Apple, Inc.                                132
# Intel Corporate                             77
# Samsung Electronics Co.,Ltd                  7
# SAMSUNG ELECTRO-MECHANICS(THAILAND)          6
# Hon Hai Precision Ind. Co.,Ltd.              3
# Silex Technology, Inc.                       1
# Sony Corporation                             1
# Rivet Networks                               1
# Huawei Device Co., Ltd.                      1
# BlackBerry RTS                               1
# Liteon Technology Corporation                1
# Motorola Mobility LLC, a Lenovo Company      1
# Shenzhen RF Technology Co., Ltd              1
# Microsoft Corporation                        1
# Name: Manufacturer, dtype: int64

# %%
# test
random = security_guard_1.sample(n=5)
random
# Out:
#          ClientMacAddr      0_x  0_y
# 133  5c:5f:67:8b:f2:45   2520.0  NaN
# 140  5c:5f:67:8c:17:a7   5102.0  NaN
# 25   0c:3e:9f:e8:9d:69  16919.0  1.0
# 317  a0:4e:a7:91:a9:c2   1903.0  1.0
# 165  7c:b2:7d:85:d7:b1    352.0  NaN

# %%
# test
random = security_guard_2.sample(n=5)
random
# Out:
#          ClientMacAddr     0_x  0_y
# 229  ec:ad:b8:8e:01:ac   19003    1
# 78   50:de:06:28:65:49  114568    1
# 174  9c:da:3e:7f:8e:92    1268    1
# 59   38:f9:d3:20:2d:c0     753    1
# 213  cc:44:63:3c:40:9e   52537    1

# %%
# security_guard_1 1
use_data = employee_data[employee_data['ClientMacAddr']=='5c:5f:67:8b:f2:45']

plt.figure(figsize=(16,9))

# Plot the enclosed shape
b = [51.46094763183397, 
     51.46092976598236,
     51.460257062787136,
     51.46033182761984,
     51.46055317954987,
     51.46051343244503,
     51.46094763183397]
a = [-0.9324647751707785,
     -0.9321732468412318,
     -0.9322924232674887,
     -0.9332446313023279,
     -0.9332078677279798,
     -0.9325475994237232,
     -0.9324647751707785]
plt.plot(a,b)
plt.scatter('lng','lat',data = use_data, s = 2)

# Set the x and y limits of the plot
plt.xlim(-0.9333, -0.93215)
plt.ylim(51.46025, 51.460962917873445)

# Remove the x ticks and y ticks
plt.xticks([])
plt.yticks([])

# Set the x and y labels of the plot
plt.xlabel('Longtitude')
plt.ylabel('Latitude')

# Show the plot
plt.show()

# %%
# security_guard_1 2
use_data = employee_data[employee_data['ClientMacAddr']=='5c:5f:67:8c:17:a7']

plt.figure(figsize=(16,9))

# Plot the enclosed shape
b = [51.46094763183397, 
     51.46092976598236,
     51.460257062787136,
     51.46033182761984,
     51.46055317954987,
     51.46051343244503,
     51.46094763183397]
a = [-0.9324647751707785,
     -0.9321732468412318,
     -0.9322924232674887,
     -0.9332446313023279,
     -0.9332078677279798,
     -0.9325475994237232,
     -0.9324647751707785]
plt.plot(a,b)
plt.scatter('lng','lat',data = use_data, s = 2)

# Set the x and y limits of the plot
plt.xlim(-0.9333, -0.93215)
plt.ylim(51.46025, 51.460962917873445)

# Remove the x ticks and y ticks
plt.xticks([])
plt.yticks([])

# Set the x and y labels of the plot
plt.xlabel('Longtitude')
plt.ylabel('Latitude')

# Show the plot
plt.show()

# %%
# security_guard_1 3
use_data = employee_data[employee_data['ClientMacAddr']=='0c:3e:9f:e8:9d:69']

plt.figure(figsize=(16,9))

# Plot the enclosed shape
b = [51.46094763183397, 
     51.46092976598236,
     51.460257062787136,
     51.46033182761984,
     51.46055317954987,
     51.46051343244503,
     51.46094763183397]
a = [-0.9324647751707785,
     -0.9321732468412318,
     -0.9322924232674887,
     -0.9332446313023279,
     -0.9332078677279798,
     -0.9325475994237232,
     -0.9324647751707785]
plt.plot(a,b)
plt.scatter('lng','lat',data = use_data, s = 2)

# Set the x and y limits of the plot
plt.xlim(-0.9333, -0.93215)
plt.ylim(51.46025, 51.460962917873445)

# Remove the x ticks and y ticks
plt.xticks([])
plt.yticks([])

# Set the x and y labels of the plot
plt.xlabel('Longtitude')
plt.ylabel('Latitude')

# Show the plot
plt.show()

# %%
# security_guard_1 4
use_data = employee_data[employee_data['ClientMacAddr']=='a0:4e:a7:91:a9:c2']

plt.figure(figsize=(16,9))

# Plot the enclosed shape
b = [51.46094763183397, 
     51.46092976598236,
     51.460257062787136,
     51.46033182761984,
     51.46055317954987,
     51.46051343244503,
     51.46094763183397]
a = [-0.9324647751707785,
     -0.9321732468412318,
     -0.9322924232674887,
     -0.9332446313023279,
     -0.9332078677279798,
     -0.9325475994237232,
     -0.9324647751707785]
plt.plot(a,b)
plt.scatter('lng','lat',data = use_data, s = 2)

# Set the x and y limits of the plot
plt.xlim(-0.9333, -0.93215)
plt.ylim(51.46025, 51.460962917873445)

# Remove the x ticks and y ticks
plt.xticks([])
plt.yticks([])

# Set the x and y labels of the plot
plt.xlabel('Longtitude')
plt.ylabel('Latitude')

# Show the plot
plt.show()

# %%
# security_guard_1 5
use_data = employee_data[employee_data['ClientMacAddr']=='7c:b2:7d:85:d7:b1']

plt.figure(figsize=(16,9))

# Plot the enclosed shape
b = [51.46094763183397, 
     51.46092976598236,
     51.460257062787136,
     51.46033182761984,
     51.46055317954987,
     51.46051343244503,
     51.46094763183397]
a = [-0.9324647751707785,
     -0.9321732468412318,
     -0.9322924232674887,
     -0.9332446313023279,
     -0.9332078677279798,
     -0.9325475994237232,
     -0.9324647751707785]
plt.plot(a,b)
plt.scatter('lng','lat',data = use_data, s = 2)

# Set the x and y limits of the plot
plt.xlim(-0.9333, -0.93215)
plt.ylim(51.46025, 51.460962917873445)

# Remove the x ticks and y ticks
plt.xticks([])
plt.yticks([])

# Set the x and y labels of the plot
plt.xlabel('Longtitude')
plt.ylabel('Latitude')

# Show the plot
plt.show()

# %%
# security_guard_2 1
use_data = employee_data[employee_data['ClientMacAddr']=='ec:ad:b8:8e:01:ac']

plt.figure(figsize=(16,9))

# Plot the enclosed shape
b = [51.46094763183397, 
     51.46092976598236,
     51.460257062787136,
     51.46033182761984,
     51.46055317954987,
     51.46051343244503,
     51.46094763183397]
a = [-0.9324647751707785,
     -0.9321732468412318,
     -0.9322924232674887,
     -0.9332446313023279,
     -0.9332078677279798,
     -0.9325475994237232,
     -0.9324647751707785]
plt.plot(a,b)
plt.scatter('lng','lat',data = use_data, s = 2)

# Set the x and y limits of the plot
plt.xlim(-0.9333, -0.93215)
plt.ylim(51.46025, 51.460962917873445)

# Remove the x ticks and y ticks
plt.xticks([])
plt.yticks([])

# Set the x and y labels of the plot
plt.xlabel('Longtitude')
plt.ylabel('Latitude')

# Show the plot
plt.show()

# %%
# security_guard_2 2
use_data = employee_data[employee_data['ClientMacAddr']=='50:de:06:28:65:49']

plt.figure(figsize=(16,9))

# Plot the enclosed shape
b = [51.46094763183397, 
     51.46092976598236,
     51.460257062787136,
     51.46033182761984,
     51.46055317954987,
     51.46051343244503,
     51.46094763183397]
a = [-0.9324647751707785,
     -0.9321732468412318,
     -0.9322924232674887,
     -0.9332446313023279,
     -0.9332078677279798,
     -0.9325475994237232,
     -0.9324647751707785]
plt.plot(a,b)
plt.scatter('lng','lat',data = use_data, s = 2)

# Set the x and y limits of the plot
plt.xlim(-0.9333, -0.93215)
plt.ylim(51.46025, 51.460962917873445)

# Remove the x ticks and y ticks
plt.xticks([])
plt.yticks([])

# Set the x and y labels of the plot
plt.xlabel('Longtitude')
plt.ylabel('Latitude')

# Show the plot
plt.show()

# %%
# security_guard_2 3
use_data = employee_data[employee_data['ClientMacAddr']=='9c:da:3e:7f:8e:92']

plt.figure(figsize=(16,9))

# Plot the enclosed shape
b = [51.46094763183397, 
     51.46092976598236,
     51.460257062787136,
     51.46033182761984,
     51.46055317954987,
     51.46051343244503,
     51.46094763183397]
a = [-0.9324647751707785,
     -0.9321732468412318,
     -0.9322924232674887,
     -0.9332446313023279,
     -0.9332078677279798,
     -0.9325475994237232,
     -0.9324647751707785]
plt.plot(a,b)
plt.scatter('lng','lat',data = use_data, s = 2)

# Set the x and y limits of the plot
plt.xlim(-0.9333, -0.93215)
plt.ylim(51.46025, 51.460962917873445)

# Remove the x ticks and y ticks
plt.xticks([])
plt.yticks([])

# Set the x and y labels of the plot
plt.xlabel('Longtitude')
plt.ylabel('Latitude')

# Show the plot
plt.show()

# %%
# security_guard_2 4
use_data = employee_data[employee_data['ClientMacAddr']=='38:f9:d3:20:2d:c0']

plt.figure(figsize=(16,9))

# Plot the enclosed shape
b = [51.46094763183397, 
     51.46092976598236,
     51.460257062787136,
     51.46033182761984,
     51.46055317954987,
     51.46051343244503,
     51.46094763183397]
a = [-0.9324647751707785,
     -0.9321732468412318,
     -0.9322924232674887,
     -0.9332446313023279,
     -0.9332078677279798,
     -0.9325475994237232,
     -0.9324647751707785]
plt.plot(a,b)
plt.scatter('lng','lat',data = use_data, s = 2)

# Set the x and y limits of the plot
plt.xlim(-0.9333, -0.93215)
plt.ylim(51.46025, 51.460962917873445)

# Remove the x ticks and y ticks
plt.xticks([])
plt.yticks([])

# Set the x and y labels of the plot
plt.xlabel('Longtitude')
plt.ylabel('Latitude')

# Show the plot
plt.show()

# %%
# security_guard_2 5
use_data = employee_data[employee_data['ClientMacAddr']=='cc:44:63:3c:40:9e']

plt.figure(figsize=(16,9))

# Plot the enclosed shape
b = [51.46094763183397, 
     51.46092976598236,
     51.460257062787136,
     51.46033182761984,
     51.46055317954987,
     51.46051343244503,
     51.46094763183397]
a = [-0.9324647751707785,
     -0.9321732468412318,
     -0.9322924232674887,
     -0.9332446313023279,
     -0.9332078677279798,
     -0.9325475994237232,
     -0.9324647751707785]
plt.plot(a,b)
plt.scatter('lng','lat',data = use_data, s = 2)

# Set the x and y limits of the plot
plt.xlim(-0.9333, -0.93215)
plt.ylim(51.46025, 51.460962917873445)

# Remove the x ticks and y ticks
plt.xticks([])
plt.yticks([])

# Set the x and y labels of the plot
plt.xlabel('Longtitude')
plt.ylabel('Latitude')

# Show the plot
plt.show()
